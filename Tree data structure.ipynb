# %%
def Node(root):
    def __init__(self,key,left=None,right=None):
        self.left=left
        self.right=right
        self.val=key
        
def printInorder(root):
    if root:
        print(root.left)
        print(root.val)
        print(root.right)
def printpostOrder(root):
    if root:
        print(root.left)
        print(root.right)
        print(root.val)
def printpreorder(root):
    if root:
        print(root.val)
        print(root.left)
        print(root.right)
        
root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)

printpreorder(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9116\2693887961.py in <module>
#      22
#      23 root=Node(1)
# ---> 24 root.left=Node(2)
#      25 root.right=Node(3)
#      26 root.left.left=Node(4)
#
# AttributeError: 'NoneType' object has no attribute 'left'

# %%
class solution:
    def __init__(self,val,left=None,right=None):
        self.val=val
        self.right=right
        self.left=left
        
class solution:
    def inordertraversal(self,root):
        res=[]
        def inorder(root):
            if not root:
                return
            inorder(root.left)
            res.append(root.val)
            inorder(root.right)
            res.append(root.right)
        inorder(root)
        return res

# %%
class solution:
    def __init__(self,val,left=None,right=None):
        self.val=val
        self.right=right
        self.left=left
        
class solution:
    def inorderTraversal(self,root):
        res=[]
        stack=[]
        curr=root
        while cur or stack:
            while cur:
                stack.append(cur)
                cur=cur.left
            cur=stack.pop()
            res.append(cur)
            cur=cur.right
        return res

# %%
class UnionFind:
    def __init__(self,n):
        self.parent=[i for i in range(n)]
        self.rank=[0]*n
        
    def find(self,x):
        if self.parent[x]!=x:
            self.parent[x]=self.find(self.parent[x])
        return self.parent[x]
    
    def union(self,x,y):
        root_x=self.find(x)
        root_y=self.find(y)
        if root_x!=root_y:
            if self.rank[root_x]>self.rank[root_y]:
                self.parent[root_y]=root_x
            elif self.rank[root_x]<self.rank[root_y]:
                self.parent[root_x]=root_y
            else:
                self.parent[root_y]=root_x
                self.rank[root_x]+=1
                

def krushkal(graph):
    edges=sorted((weight,u,v)for u,neighbours in graph.items() for v,weight in neighbours.items())
    num_vertices=len(graph)
    mst=[]
    
    uf=UnionFind(num_vertices)
    for weight,u,v in edges:
        if uf.find(u)!=uf.find(v):
            uf.union(u,v)
            mst.append((u,v,weight))
    return mst
    
if __name__ == "__main__":
    # Example usage:
    graph = {
        0: {1: 5, 2: 10},
        1: {0: 5, 2: 8, 3: 6},
        2: {0: 10, 1: 8, 3: 2},
        3: {1: 6, 2: 2},
    }

    minimum_spanning_tree = krushkal(graph)
    print("Minimum Spanning Tree:")
    for u, v, weight in minimum_spanning_tree:
        print(f"{u} -- {v} : {weight}")
# Out:
# Minimum Spanning Tree:
# 2 -- 3 : 2
# 0 -- 1 : 5
# 1 -- 3 : 6

# %%
def petrol_circlar(petrol,dist,n):
    sum=0
    starting=0
    diff=0
    for i in range(n):
        sum=sum+petrol[i]-dist[i]
        if sum<0:
            starting=i+1
            diff=diff+sum
            sum=0
    if sum+diff>0:
        return starting
    else:
        return -1
    
p=[7,1,0,11,4]
d=[5,9,1,2,5]
circular=petrol_circular(p,d,5)
print(circular)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5660\1076372103.py in <module>
#      16 p=[7,1,0,11,4]
#      17 d=[5,9,1,2,5]
# ---> 18 circular=petrol_circular(p,d,5)
#      19 print(circular)
#
# NameError: name 'petrol_circular' is not defined

# %%
# Kth Smallest Element in a BST
# Given a binary search tree, write a function kthSmallest to find the kth smallest
# element in it.
# Note: You may assume k is always valid, 1 ≤ k ≤ BST's total elements.
# Follow up: What if the BST is modified (insert/delete operations) often and you
# need to find the kth smallest frequently? How would you optimize the kthSmallest
# routine?
# Hint:
# Try to utilize the property of a BST. What if you could modify the BST node's
# structure? The optimal runtime complexity is O(height of BST

class TreeNode(object):
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution(object):
    def Kthsmallestelement(self,root,k):
        if root==None:
            return None
        else:
            stack=[]
            node=root
            count=0
            while stack!=[] or node!=None:
                if node!=None:
                    stack.append(node)
                    node=node.left
                else:
                    inorder_node=stack.pop()
                    count+=1
                    if count==k:
                        return inorder_node.val
                    node=inorder_node.right
            return None

# %%
class TreeNode:
   def __init__(self, data, left = None, right = None):
      self.data = data
      self.left = left
      self.right = right
def print_tree(root):
   #print using inorder traversal
   if root is not None:
      print_tree(root.left)
      print(root.data, end = ', ')
      print_tree(root.right)
    
class Solution(object):
   def buildTree(self, preorder, inorder):
    
    if inorder:
        
        root = TreeNode(preorder.pop(0))
        root_index = inorder.index(root.data)
        root.left = self.buildTree(preorder,inorder[:root_index])
        root.right = self.buildTree(preorder,inorder[root_index+1:])
        return root

# %%
class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
class BSTIterator:
    def __init__(self,root):
        self.stack=[]
        node=root
        while node!=None:
            self.stack.append(node)
            node=node.left
            
    def hasNext(self):
        return len(stack)!=0
    
    def next(self):
        nextnode=self.stack.pop()
        currnode=nextnode.right
        while currnode!=None:
            self.stack.append(currnode)
            currnode=currentnode.left
        return nextnode.val
    
i,v=BSTIterator(node),[]
while i.hasNext():
    v.append(i.next)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17900\2881898267.py in <module>
#      24         return nextnode.val
#      25
# ---> 26 i,v=BSTIterator(node),[]
#      27 while i.hasNext():
#      28     v.append(i.next)
#
# NameError: name 'node' is not defined

# %%
def inordertraversal(self,root):
    if root==None:
        return []
    else:
        result=[]
        stack=[]
        node=root
        while stack or node:
            if node:
                stack.append(node)
                node=node.left
            else:
                node=stack.pop()
                result.append(node.val)
                node=node.right
        return result

# %%
class solution(object):
    def isSymmetric(self,root):
        if root==None:
            return True
        else:
            return self.ismirror(root.left,root.right)
        
    def isMirror(self,root1,root2):
        if root1==None and root2==None:
            return True
        elif root1==None and root2==None:
            return False
        else:
            if root1.val==root2.val:
                return self.isMirror(root1.left,root.right) and self.ismirror(root1.root.right,root2.left)
            else:
                return False

# %%
# Balenced Binary Tree
class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
class solution:
    def getHeight(self,root):
        if root==None:
            return 0
        leftHeight=self.getHeight(root.left)
        if leftHeight==-1:
            return -1
        rightHeight=self.getHeight(root.right)
        if rightHeight==-1:
            return -1
        heightDiff=abs(leftHeiht-rightHeight)
        if heightDiff>1:
            return -1
        else:
            return max(leftHeight,rightHeight)+1
        
    def isBalenced(self,root):
        if self.getHeight(root)==-1:
            return False
        else:
            return True

# %%
# closest Binarysearch Tree value
class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
class solution(object):
    def closestValue(self,root,target):
        min_diff("inf")
        closest_val=None
        
        if root==None:
            return None
        else:
            while root:
                root_val=root.val
                val_diff=abs(root_val-target)
                if val_diff<min:
                    min_diff=val_diff
                    closest_val=root_val
                if target<root.val:
                    if root.left!=None:
                        root=root.left
                    else:
                        root=None
                else:
                    if root.right!=None:
                        root=root.right
                    else:
                        root=None
        return closest_val

# %%
# Postorder Traversal
# Given a binary tree, return the postorder traversal of its nodes' values.
# For example: Given binary tree {1,#,2,3}, 1 \ 2 / 3 return [3,2,1].
# Note: Recursive solution is trivial, could you do it iteratively?

class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
class solution(object):
    def postordertraversal(self,root):
        if root==None:
            return []
        else:
            stack=[]
            out_stack=[]
            stack.append(root)
            
            while stack!=[]:
                current=stack.pop()
                out.stack.append(current.val)
                if current.left!=None:
                    stack.append(current.left)
                if current.right!=None:
                    stack.append(current.right)
            return out_stack[::-1]

# %%
class newNode:
    def __init__(self,data):
        self.data=data
        self.left=self.right=None
       
class solution:
    def mirror(node):
        if node==None:
            return
        else:
            temp=node
            
            #do the subtrees
            mirror(node.left)
            mirror(node.right)
            #swap
            temp=node.left
            node.left=node.right
            node.right=temp
            
def inorder(node):
    if root==None:
        return
    inorder(node.left)
    print(node.data,end=" ")
    inorder(node.right)
    
if __name__ == "__main__":
 
    root = newNode(1)
    root.left = newNode(2)
    root.right = newNode(3)
    root.left.left = newNode(4)
    root.left.right = newNode(5)
 
    """ Print inorder traversal of
        the input tree """
    print("Inorder traversal of the",
          "constructed tree is")
    inorder(root)
 
    """ Convert tree to its mirror """
    mirror(root)
    """ Print inorder traversal of
        the mirror tree """
    print("\nInorder traversal of",
          "the mirror tree is ")
    inorder(root)
# Out:
# Inorder traversal of the constructed tree is
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6548\2998257446.py in <module>
#      38     print("Inorder traversal of the",
#      39           "constructed tree is")
# ---> 40     inorder(root)
#      41
#      42     """ Convert tree to its mirror """
#
# ~\AppData\Local\Temp\ipykernel_6548\2998257446.py in inorder(node)
#      22     if root==None:
#      23         return
# ---> 24     inorder(node.left)
#      25     print(node.data,end=" ")
#      26     inorder(node.right)
#
# ~\AppData\Local\Temp\ipykernel_6548\2998257446.py in inorder(node)
#      22     if root==None:
#      23         return
# ---> 24     inorder(node.left)
#      25     print(node.data,end=" ")
#      26     inorder(node.right)
#
# ~\AppData\Local\Temp\ipykernel_6548\2998257446.py in inorder(node)
# ...

# %%
# In this method, we invert the given binary tree by swapping the left and right nodes and recursively carrying out the same process for each non-leaf node until we reach the leaf node.

# Steps to invert a Binary Tree:

# If root/ current node is NULL, inverting is done.
# For current node N, swap left and right child nodes.
# Process new left and right child with step 1 and 2 recursively.

class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
class Inversion:
    def invert(self,root):
        if root==None:
            return None
        
        #swapping the children
        temp=root.left
        root.left=root.right
        root.right=temp
        
        #recursion
        self.invert(root.left)
        self.invert(root.right)
        return root

# %%
# Steps to invert a Binary Tree iteratively using Stack:

# If root/ current node is NULL, inverting is done.
# Define a stack S.
# Add root node to stack S.
# While stack S is not empty:
# 4.1. Pop node N from stack S
# 4.2. Swap left and right child of node N
# 4.3. Push new left and right child of node N to stack S.
# The Binary Tree is inverted


class Inversion:
    def swap(root):
        if root==None:
            return
        #swapping the children
        temp=root.left
        root.left=root.right
        root.right=temp
        
    def invert(root):
        if root==None:
            return
        
        stack=[]
        stack.append(root)
        while stack!=[]:
            curr=stack.pop()
            stack.append(curr)
            swap(curr)
            if curr.left:
                stack.append(curr.left)
            if curr.right:
                stack.append(curr.right)

# %%
class Inversion:
    def swap(root):
        if root==None:
            return
        #swapping the children
        temp=root.left
        root.left=root.right
        root.right=temp
        
    def invert(root):
        if root==None:
            return
        q=Queue()
        q.put(root)
        while(q.empty()!=True):
            curr=q.popleft()
            swap(curr)
            if curr.left:
                q.put(curr.left)
            if curr.right:
                q.put(curr.right)

# %%
class TreeNode:
    def __init__(self,x,left=None,right=None):
        self.val=None
        self.left=left
        self.right=right
        
    def isSameTree(self,p,q):
        if p==None and q==None:
            return True
        else:
            if p.val==q.val:
                return False
            else:
                if p.val==q.val:
                    return self.isSame

# %%
# Lowest Common Ancestor of a Binary
# Search Tre

class solution(object):
    def __init__(self):
        self.inorder_list=[]
        self.postorder_list=[]
        
    def lowestCommonAncestor(self,root,p,q):
        if root==None:
            return None
        
        else:
            self.inorder_traversal(root)
            self.postorder_traversal(root)
            #get the postions of node1 and node2
            index_1=self.inorder_list.index(p.val)
            index_2=self.inorder_list.index(q.val)
            
            if index_1<index_2:
                between_elems=self.inorder_list[index_1:index_2+1]
            else:
                between_elems=self.inorder_list[index_2:index_1+1]
            lca_elem=self.find_elem_max_index(between_elems)
            return lca_elem
    
    def finf_elem_max_index(self,between_elems):
        max_index=-1
        elem=None
        for i in between_elems:
            elem_index=self.postorder_list.index(i)
            if elem_index>max_index:
                max_index=elem_index
                elem=i
        return elem
    
    def inorder_traversal(self,node):
        if node:
            self.inorder_traversal(node.left)
            self.inorder_list.append(node.val)
            self.inorder_traversal(node.right)
    
    def postorder_traversal(self,node):
        if node:
            self.postorder_traversal(node.left)
            self.postorder_traversal(node.right)
            self.postorder_list.append(node.val)

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    
def findSecondMinimumValue(root):
    if root is None:
        return -1
    if root.left==None and root.right==None:
        return-1
    left=root.left.data
    right=root.right.data
    
    if root.data==root.left.data:
        left=findSecondMinimumValue(root.val)
    if root.data==root.right.data:
        right=findSecondMinimumValue(root.right)
        
    if left!=-1 and right!=-1:
        return min(left,right)
    elif left!=-1:
        return left
    else:
        return right
    
root = Node(2)
root.left = Node(3)
root.right = Node(2)
root.right.left = Node(8)
root.right.right = Node(2)
root.left.left = Node(3)
root.left.right = Node(6)
root.left.left.left = Node(3)
root.left.left.right = Node(5)
root.left.right.left = Node(6)
root.left.right.right = Node(7)
root.right.left.left = Node(20)
root.right.left.right = Node(8)
root.right.right.right = Node(9)
root.right.right.left = Node(2)

print(findSecondMinimumValue(root))
a=Node()
a.findSecondMinimumValue(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19808\496434260.py in <module>
#      41 root.right.right.left = Node(2)
#      42
# ---> 43 print(findSecondMinimumValue(root))
#      44 a=Node()
#      45 a.findSecondMinimumValue(root)
#
# ~\AppData\Local\Temp\ipykernel_19808\496434260.py in findSecondMinimumValue(root)
#      16         left=findSecondMinimumValue(root.val)
#      17     if root.data==root.right.data:
# ---> 18         right=findSecondMinimumValue(root.right)
#      19
#      20     if left!=-1 and right!=-1:
#
# ~\AppData\Local\Temp\ipykernel_19808\496434260.py in findSecondMinimumValue(root)
#      16         left=findSecondMinimumValue(root.val)
#      17     if root.data==root.right.data:
# ---> 18         right=findSecondMinimumValue(root.right)
#      19
#      20     if left!=-1 and right!=-1:
#
# ...

# %%
class TreeNode(object):
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class codec:
    def __init__(self):
        self.serialized_array=[]
        self.index=0
        
def serialize(self,root):
    self.serialization_help(root)
    return self.serialized_array

def serialization_help(self,root):
    if root==None:
        self.serialized_array.append(None)
        return
    self.serialized_array.append(root.val)
    self.serialize(root.left)
    self.serialize(root.right)
        
    def deserialize(self,data):
        if self.index==len(data) or data[self.index]==None:
            self.index+=1
            return None
        root=TreeNode(data[self.index])
        self.index+=1
        root.left=self.deserialize(data)
        root.right=self.deserialize(data)
        return root
    
Codec=codec()
# Codec.deserialize(codec.serialize(root))

# %%
# tree leet code problems

# %%
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class solution(object):
    def preorderTraversal(self,root):
        if root==None:
            return []
        else:
            preorderlist=[]
            stack=[]
            stack.append(root)
            while(stack!=[]):
                node=stack.pop()
                preorderlist.append(node.val)
                if node.right:
                    stack.append(node.right)
                if node.left:
                    stack.append(node.left)
            return preorderlist
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

s=solution()
s.preorderTraversal(root)
# Out:
# [1, 2, 4, 5, 3]

# %%
# Binary tree iteratior
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class BTSIterator:
    def __init__(self,root):
        self.stack=[]
        node=root
        while node!=None:
            self.stack.append(node)
            node=node.left
            
    def hasNext(self):
        return len(self.stack)!=0
    
    def next(self):
        nextNode=self.stack.pop()
        currentNode=nextNode.right
        while currentNode!=None:
            self.stack.append(currentNode)
            currentNode=currentNode.left

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left= TreeNode(8)
root.right.right = TreeNode(9)
root.left.left.right = TreeNode(4)
root.left.right.left = TreeNode(5)


i,v=BTSIterator(root),[]
while i.hasNext():
    v.append(i.next())

# a=BTSIterator.next()

# %%
#Inorder Traversal
class TreeNode:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def inorderTraversal(self,root):
        if root==None:
            return []
        
        else:
            result=[]
            stack=[]
            node=root
            while stack or node:
                if node:
                    stack.append(node)
                else:
                    node=stack.pop()
                    result.append(node.val)
                    node=node.right
            return result
        
# if __name__ == "__main__":
#     root = Node(1)
#     root.left = Node(2)
#     root.right = Node(3)
#     root.left.left = Node(4)
#     root.left.right = Node(5)
#     s=solution()
#     print(s.inorderTraversal(root))
root = TreeNode(1)
root.left =TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
s=solution()
print(s.inorderTraversal(root))

# %%
##Symmetric binary tree

class solution:
    def issymmetric(self,root):
        if root==None:
            return True
        else:
            return self.ismirror(root.left,root.right)
        
    def ismirror(self,root1,root2):
        if root1==None and root2==None:
            return True
        elif root1==None and root2==None:
            return False
        else:
            if root1.val==root2.val:
                return self.ismirror(root1.left,root2.right) and self.ismirror(root1.right,root1.left)
            else:
                return False

# %%
##height of a binary tree
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
def height_BinaryTree(A):
    if A==None:
            return 0
    else:
        ldepth=height_BinaryTree(A.left)
        rdepth=height_BinaryTree(A.right)
        if ldepth>rdepth:
            return (1+ldepth)
        else:
            return (1+rdepth)
        
            
root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)
root.left.left.left=Node(6)
root.left.right.left=Node(7)
height_BinaryTree(root)
# Out:
# 4

# %%
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def getHeight(self,root):
        if root==None:
            return 0
        
        leftHeight=self.getHeight(root.left)
        if leftHeight==-1:
            return -1
        
        rightHeight=self.getHeight(root.right)
        if rightHeight==-1:
            return -1
        
        heightdiff=abs(leftHeight-rightHeight)
        if heightdiff>1:
            return -1
        else:
            return max(leftHeight,rightHeight)
        
    def isBalanced(self,root):
        if self.getHeight(root)==-1:
            return False
        else:
            return True
        
root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)
root.left.left.left=Node(6)
root.left.right.left=Node(7)

x=solution()
x.getHeight(root)
# Out:
# 0

# %%
# closest binary Tree
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def closestvalue(self,root,target):
        min_diff=float('inf')
        closest_val=None
        if root==None:
            return 0
        else:
            while root:
                root_val=root.val
                val_diff=abs(root.val-target)
                if val_diff<min_diff:
                    min_diff=val_diff
                    closestval=root_val
                if target<root.val:
                    if root.left!=None:
                        root=root.left
                    else:
                        root=None
                        
                else:
                    if root.right!=None:
                        root=root.right
                    else:
                        root=None
                        
        return closestval
    
root=Node(1)
root.left=Node(2)
root.right=Node(3)
root.left.left=Node(4)
root.left.right=Node(5)
root.left.left.left=Node(6)
root.left.right.left=Node(7)
a=solution()
a.closestvalue(root,2)
# Out:
# 1

# %%
#postorder traversal
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None

class solution:
    def postordertraversal(self,root):
        if root==None:
            return []
        else:
            stack=[]
            result=[]
            stack.append(root)
            while stack!=[]:
                curr=stack.pop()
                result.append(curr.val)
                if curr.left!=None:
                    stack.append(curr.left)
                if curr.right!=None:
                    stack.append(curr.right)
                    
            return result[::-1]
        
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
a=solution()
a.postordertraversal(root)
# Out:
# [4, 5, 2, 3, 1]

# %%
#max depth of Binary Tree
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def maxdepth(self,root):
        if root==None:
            return 0
        else:
            return max(self.maxdepth(root.left),self.maxdepth(root.right))+1

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
a=solution()
a.maxdepth(root)
# Out:
# 3

# %%
##Invert Tree
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def invertTree(self,root):
        if root==None:
            return None
        else:
            stack=[]
            stack.append(root)
            while stack!=[]:
                curr_node=stack.pop()
                if curr_node.left!=None or curr_node.right!=None:
                    temp=curr_node.left
                    curr_node.left=curr_node.right
                    curr_node.right=temp
                
                if curr_node.right!=None:
                    stack.append(curr_node.right)
                    
                if curr_node.left!=None:
                    stack.append(curr_node.left)
            return root
        
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
a=solution()
a.invertTree(root)

# %%
####lowest common ancestor in a Binary Tree

class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
def lowestcommonAncestor(self,root,p,q):
    if root==None:
        return root
    
    if root==p or root==q:
        return root
    
    left=self.lowestcommonAncestor(root.left,p,q)
    right=self.lowestcommonAncestor(root.right,p,q)
    
    if left!=None and right!=None:
        return root
    
    if left==None:
        return right
    else:
        return left
    
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# %%
###unique Binary trees

def numtrees(self,n):
    solutions=[-1]*n
    return self.numUniqueBST(n,solutions)

def numUniqueBST(self,n,solutions):
    if n<0:
        return 0
    
    if n==0 or n==1:
        return -1
    
    possibilities=0
    
    for i in range(0,n):
        if solutions[i]==-1:
            solutions[i]=self.numUniqueBST(i,solutions)
        if solutions[n-1-i]==-1:
            solutions[n-1-i]=self.numUniqueBST(n-1-i,solutions)
            
        possibilities+=solutions[i]*solutions[n-1-i]
    return possibilities
# n=3
# numtrees(n)

# %%
class solution:
    def numtrees(self,n):
        solutions=[-1]*n
        return self.numUniqueBST(n,solutions)
    
    def numUniqueBST(self,n,solutions):
        if n<0:
           return 0
    
        if n==0 or n==1:
           return -1
    
        possibilities=0
    
        for i in range(0,n):
            if solutions[i]==-1:
                solutions[i]=self.numUniqueBST(i,solutions)
            if solutions[n-1-i]==-1:
                solutions[n-1-i]=self.numUniqueBST(n-1-i,solutions)
            
            possibilities+=solutions[i]*solutions[n-1-i]
        return possibilities
a=solution()
a.numtrees(5)
# Out:
# 6

# %%
#Unique Binary Search Trees II
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
class solution:
    def generateTrees(self,n):
        if n==0:
            return []
        else:
            return self.tree_constructor(1,n)
        
    def tree_constructor(self,m,n):
        result=[]
        if m > n:
            result.append(None)
            return result
        
        for i in range(m,n+1):
            l=self.tree_constructor(m,i-1)
            r=self.tree_constructor(i+1,n)
            for left_trees in l:
                for right_trees in r:
                    curr=Node(i)
                    curr.left=left_trees
                    curr.right=right_trees
                    result.append(curr)
        return result
    
x=solution()
m=2
n=8
x.generateTrees(6)

# %%
# Path Sum
# Given a binary tree and a sum, determine if the tree has a root-to-leaf path such
# that adding up all the values along the path equals the given sum.
# For example: Given the below binary tree and sum = 22, 5 / \ 4 8 / / \ 11 13 4 / \ \ 7
# 2 1 return true, as there exist a root-to-leaf path 5->4->11->2 which sum is 22.

class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
class solution:
    def haspathsum(self,root,sum):
        if root==None:
            return True
        else:
            curr=root
            s=[]
            s.append(curr)
            s.append(curr.val)
            
            while s!=[]:
                pathsum=s.pop()
                curr=s.pop()
                
                if pathsum==sum:
                    return True
                
            if curr.right:
                rightpathsum=pathsum+curr.right.val
                s.append(curr.right)
                s.append(rightpathsum)
                
            if curr.left:
                leftpathsum=pathsum+curr.left.val
                s.append(curr.left)
                s.append(leftpathsum)
                
        return False
    
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
x=solution()
sum=10
x.haspathsum(root,sum)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17108\3086776586.py in <module>
#      47 x=solution()
#      48 sum=10
# ---> 49 x.haspathsum(root,sum)
#
# ~\AppData\Local\Temp\ipykernel_17108\3086776586.py in haspathsum(self, root, sum)
#      19             s=[]
#      20             s.append(curr)
# ---> 21             s.append(curr.val)
#      22
#      23             while s!=[]:
#
# AttributeError: 'Node' object has no attribute 'val'

# %%
# Binary Tree maximum path sum
import sys
class Node(object):
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution(object):
    def __init__(self):
        self.maxSum=-sys.maxsize-1
        
    def maxpathsum(self,root):
        self.findmax(root)
        return self.maxSum
    
    def findmax(self,root):
        if root==None:
            return 0
        
        left=self.findmax(root.left)
        right=self.findmax(root.right)
        self.maxSum=max(root.val+left+right,self.maxSum)
        ret=root.val+max(left,right)
        if ret<0:
            return 0
        else:
            return ret
        
root = Node(1)
root.left = Node(2)
root.right = Node(3)
# root.left.left = Node(4)
# root.left.right = Node(5)
x=solution()
x.maxpathsum(root)
# Out:
# 6

# %%
from collections 
# Binary Tree Level Order Traversal
class Node(object):
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def levelorder(self,root):
        if root==None:
            return []
        
        else:
            q=Queue.Queue()
            q.put('#')
            levelordertraversal=[]
            level=[]
            while q.empty()==False:
                node=q.get()
                if node=='#':
                    if q.empty()==False:
                        q.put('#')
                    levelordertraversal.append(level)
                    level=[]
                else:
                    level.append(node.val)
                    if node.left:
                        q.put(node.left)
                    if node.right:
                        q.put(node.right)
            return levelordertraversal

root = [3,9,20,15,7]
x=solution()
x.levelorder(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15896\1145803522.py in <module>
#      33 root = [3,9,20,15,7]
#      34 x=solution()
# ---> 35 x.levelorder(root)
#
# ~\AppData\Local\Temp\ipykernel_15896\1145803522.py in levelorder(self, root)
#      12
#      13         else:
# ---> 14             q=Queue.Queue()
#      15             q.put('#')
#      16             levelordertraversal=[]
#
# NameError: name 'Queue' is not defined

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isValidBST(self, root):
        def check(node,left,right):
            if not node:
                return True

            if not (node.val > left and node.val<right):
                return False
            
            return (check(node.left,left,node.val) and check(node.right,node.val,right))

        return check(root,float("-inf"),float("inf"))
    
x=Solution()
x.isValidBST(root)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15896\3796650457.py in <module>
#      19
#      20 x=Solution()
# ---> 21 x.isValidBST(root)
#      22
#
# ~\AppData\Local\Temp\ipykernel_15896\3796650457.py in isValidBST(self, root)
#      16             return (check(node.left,left,node.val) and check(node.right,node.val,right))
#      17
# ---> 18         return check(root,float("-inf"),float("inf"))
#      19
#      20 x=Solution()
#
# ~\AppData\Local\Temp\ipykernel_15896\3796650457.py in check(node, left, right)
#      11                 return True
#      12
# ---> 13             if not (node.val > left and node.val<right):
#      14                 return False
#      15
#
# AttributeError: 'list' object has no attribute 'val'

# %%
from typing import List
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedArrayToBST(self, nums:List[int]):

        if nums==[]:
            return None
        elif len(nums)==1:
            return TreeNode(nums[0])
        else:
            start=0
            end=len(nums)-1
            return self.to_binary(nums,start,end)

    def to_binary(self,arr,start,end):
        if len(arr)==0 and start>end:
            return None
        else:
            mid=(start+end)//2
            node=TreeNode(arr[mid])
            node.left=self.to_binary(arr,start,mid-1)
            node.right=self.to_binary(arr,mid+1,end)
            return Node
        
nums = [-10,-3,0,5,9]
x=Solution()
x.sortedArrayToBST(nums)

# %%
# Binary Tree Zigzag Level Order Traversal
def spiral_traversal(root):
    if root==None:
        return None
    
    s1=[]
    s2=[]
    s1.append(root)
    result=[]
    curr_res=[]
    while s1 or s2:
        while len(s1)>0:
            curr=s1[-1]
            curr_res.append(curr.val)
            s1.pop()
            if curr.left:
                s2.append(curr.left)
            if curr.right:
                s2.append(curr.right)
            if len(s1)==0:
                result.append(curr_res)
                curr_res=[]
        while len(s2)>0:
            curr=s2[-1]
            curr_res.append(curr.val)
            s2.pop()
            if curr.left:
                s1.append(curr.left)
            if curr.right:
                s1.append(curr.right)
            if len(s2)==0:
                result.append(curr_res)
                curr_res=[]
    return result

# %%
# Binary tree path
class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def binaryTreePaths(self,root):
        if root==None:
            return None
        else:
            paths=[]
            current=root
            s=[]
            s.append(current)
            s.append(str(current.val))
            
            while s!=[]:
                path=s.pop()
                current=s.pop()
                
                if not current.left and not current.right:
                    paths.append(path)
                if current.right:
                    rightstr=path+"->"+str(current.right.val)
                    s.append(current.right)
                    s.append(rightstr)
                
                if current.left:
                    leftstr=path+"->"+str(current.left.val)
                    s.append(current.left)
                    s.append(leftstr)
            return paths
        
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
x=solution()
x.binaryTreePaths(root)
# Out:
# ['1->2->4', '1->2->5', '1->3']

# %%
# Recover Binary Tree

class Node:
    def __init__(self,x):
        self.val=x
        self.left=None
        self.right=None
        
class solution:
    def recovertree(self,root):
        self.temp=[]
        def dfs(node):
            if not node:return
            dfs(node.left)
            self.temp.append(node)
            dfs(node.right)
        dfs(root)
        
        srt=sorted(node.val for node in self.temp)
        
        for i in range(len(srt)):
            self.temp[i].val=srt[i]

# %%
# path sum 2

class solution:
    def helper(self,root,sum_tot,lst,result):
        if root.left is None and root.right is None:
            if root.val==sum_tot:
                result+=[lst+[root.val]]
        if root.left:
            self.helper(root.left,sum_tot-root.val,lst+[root.val],result)
        if root.right:
            self.helper(root.right,sum_tot-root.val,lst+[root.val],result)
        return result
    def pathsum(self,root,sum):
        if root is None:
            return []
        return self.helper(root,sum,[],[])

# %%
# Binary level order traversal 2

def levelorderbottom(self,root):
    output=[]
    def dfs(node,level):
        if not nodeL:
            return
        if len(output)<level+1:
            output.append([])
        dfs(root.left,level+1)
        dfs(root.right,level+1)
        output[level].append(node.val)
    dfs(root,0)
    
    return output[::-1]

# %%
# flatten treee
def flatten(self,root):
    if root is None:
        return None

    flatten(root.left)
    flatten(root.right)
    if root.right is not None:
        curr=curr.right
    curr.right=root.right
    root.right=root.left
    root.left=None

# %%
#Binarytree level order traversal

class solution:
    def levelordertraversal(self,root):
        if root is None:
            return []
        queue=[]
        next_queue=[]
        level=[]
        result=[]
        while queue!=[]:
            for root in queue:
                level.append(root.val)
                if root.left is not None:
                    next_queue.append(root.left)
                if root.right is not None:
                    next_queue.append(root.right)
            result.append(level)
            level=[]
            queue=next_queue
            next_queue=[]
        return result
